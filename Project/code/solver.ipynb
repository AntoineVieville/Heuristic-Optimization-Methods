# %% [markdown]
# ### Importing librairies and utils.py

# %%
# Importing functions
from utils import *
from search import *

# %% [markdown]
# ### Processing instance data

# %%
# Load the data for instance 1
instance_1_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i1.txt'
n_vehicles_1,capacity_1,customers_1_df = read_cvrptw_instance(instance_1_path)
customers_1 = create_customers_list(customers_1_df)
depot_1 = customers_1[0]

# Load the data for instance 2
instance_2_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i2.txt'
n_vehicles_2,capacity_2,customers_2_df = read_cvrptw_instance(instance_2_path)
customers_2 = create_customers_list(customers_2_df)
depot_2 = customers_2[0]

# Load the data for instance 3
instance_3_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i3.txt'
n_vehicles_3,capacity_3,customers_3_df = read_cvrptw_instance(instance_3_path)
customers_3 = create_customers_list(customers_3_df)
depot_3 = customers_3[0]

# Load the data for instance 4
instance_4_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i4.txt'
n_vehicles_4,capacity_4,customers_4_df = read_cvrptw_instance(instance_4_path)
customers_4 = create_customers_list(customers_4_df)
depot_4 = customers_4[0]

# Load the data for instance 5
instance_5_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i5.txt'
n_vehicles_5,capacity_5,customers_5_df = read_cvrptw_instance(instance_5_path)
customers_5 = create_customers_list(customers_5_df)
depot_5 = customers_5[0]

# Load the data for instance 6
instance_6_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\i6.txt'
n_vehicles_6,capacity_6,customers_6_df = read_cvrptw_instance(instance_6_path)
customers_6 = create_customers_list(customers_6_df)
depot_6 = customers_6[0]

# Load the data for instance test
instance_test_path = r'C:\Users\Antoine\Documents\FER\Heuristic optimization\Project\instances\HMO_project_test_instance.txt'
n_vehicles_test,capacity_test,customers_test_df = read_cvrptw_instance(instance_test_path)
customers_test = create_customers_list(customers_test_df)
depot_test = customers_test[0]

# %%
# distances_1 = distance_matrix(customers_1)
# distances_2 = distance_matrix(customers_2)
# distances_3 = distance_matrix(customers_3)
# distances_4 = distance_matrix(customers_4)
# distances_5 = distance_matrix(customers_5)
# distances_6 = distance_matrix(customers_6)
distances_test = distance_matrix(customers_test)

# %%
# greedy_routes_1 = greedy_search(customers_1,n_vehicles_1,capacity_1)
# greedy_routes_2 = greedy_search(customers_2,n_vehicles_2,capacity_2)
# greedy_routes_3 = greedy_search(customers_3,n_vehicles_3,capacity_3)
# greedy_routes_4 = greedy_search(customers_4,n_vehicles_4,capacity_4)
# greedy_routes_5 = greedy_search(customers_5,n_vehicles_5,capacity_5)
# greedy_routes_6 = greedy_search(customers_6,n_vehicles_6,capacity_6)
greedy_routes_test = greedy_search(customers_test,n_vehicles_test,capacity_test)

# %%
len(greedy_routes_test)
# Out:
# 49

# %%
# # Instance test endless run:
# ACO_routes_test_un = ant_colony_optimization(customers_test,n_vehicles_test,capacity_test,2,2,0.01,4,greedy_routes_test,10)
# print(total_distance(ACO_routes_test_un,distances_test))
# print(len(ACO_routes_test_un))

# %%
# write_solution_to_file(ACO_routes_test_un,'un','i_test',distances_test)
# Out:
# Solution written to res-un-i_test.txt
